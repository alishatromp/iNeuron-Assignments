# %% [markdown]
# ## Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all?

# %% [markdown]
# ## Ans - A probability distribution is a mathematical function that describes the probability of different possible values of a variable. It tells us which value the random variable can most likely take on based on past events and data. This is how we predict the value of the random variable.

# %% [markdown]
# ----------------------

# %% [markdown]
# ## Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is one? Why are the latter considered “good enough”?

# %% [markdown]
# ## Ans - True numbers are true values and pseduo are generated by program. Pseduo - random numbers are good enough as they take the shape of uniform distrbution.

# %% [markdown]
# --------------

# %% [markdown]
# ## Q3. What are the two main factors that influence the behaviour of a &quot;normal&quot; probability distribution?

# %% [markdown]
# ## 1. Mean
# ## 2. Variance.

# %% [markdown]
# ------------

# %% [markdown]
# ## Q4. Provide a real-life example of a normal distribution.

# %% [markdown]
# ## Ans - The height, weight of population.

# %% [markdown]
# ----------

# %% [markdown]
# ## Q5. In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?

# %% [markdown]
# ## Ans - Variance will decrease with increasing number of trials.

# %% [markdown]
# -------------

# %% [markdown]
# ## Q6. What kind of object can be shuffled by using random.shuffle?

# %% [markdown]
# ## Ans - A list, string or tuple can be suffled using random.shuffle.

# %% [markdown]
# ------------

# %% [markdown]
# ## Q7. Describe the math package&#39;s general categories of functions.

# %% [markdown]
# ## Ans - Import math can do
# - Trigonometry
# - Quadratic functions
# - Exponential functions
# - Hyperbolic functions
# - Periodic functions
# - Arithmetic functions
# - Logarithimic functions
# - Conversions to Integer

# %% [markdown]
# ----------

# %% [markdown]
# ## Q8. What is the relationship between exponentiation and logarithms?

# %% [markdown]
# ## Ans - Exponential is to the power of n. Logarithmic is to the base of n.
# ## They are of an inverse relationship.

# %% [markdown]
# -------------

# %% [markdown]
# ## Q9. What are the three logarithmic functions that Python supports?

# %% [markdown]
# ## 1. log2(x) - logarithmic value of x to base 2
# ## 2. log10(x) - logarithmic value of x to base 10
# ## 3. log1p(a) - This function is used to compute logarithm(1+a) .
